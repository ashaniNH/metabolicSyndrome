# %%
import pandas as pd
df= pd.read_csv("Metabolic Syndrome.csv")
df
# Out:
#        seqn  Age     Sex  Marital  Income         Race  WaistCirc   BMI  \
# 0     62161   22    Male   Single  8200.0        White       81.0  23.3
# 1     62164   44  Female  Married  4500.0        White       80.1  23.2
# 2     62169   21    Male   Single   800.0        Asian       69.6  20.1
# 3     62172   43  Female   Single  2000.0        Black      120.4  33.3
# 4     62177   51    Male  Married     NaN        Asian       81.1  20.1
# ...     ...  ...     ...      ...     ...          ...        ...   ...
# 2396  71901   48  Female  Married  1000.0        Other        NaN  59.7
# 2397  71904   30  Female   Single  2000.0        Asian        NaN  18.0
# 2398  71909   28    Male   Single   800.0  MexAmerican      100.8  29.4
# 2399  71911   27    Male  Married  8200.0  MexAmerican      106.6  31.3
# 2400  71915   60    Male   Single  6200.0        White      106.6  27.5
#
#       Albuminuria  UrAlbCr  UricAcid  BloodGlucose  HDL  Triglycerides  \
# 0               0     3.88       4.9            92   41             84
# 1               0     8.55       4.5            82   28             56
# 2               0     5.07       5.4           107   43             78
# 3               0     5.22       5.0           104   73            141
# 4               0     8.13       5.0            95   43            126
# ...           ...      ...       ...           ...  ...            ...
# 2396            0    22.11       5.8           152   57            107
# 2397            0     2.90       7.9            91   90             91
# 2398            0     2.78       6.2            99   47             84
# 2399            0     4.15       6.2           100   41            124
# 2400            0    12.82       5.2            91   36            226
#
#       MetabolicSyndrome
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 2396                  0
# 2397                  0
# 2398                  0
# 2399                  1
# 2400                  1
#
# [2401 rows x 15 columns]

# %%
duplicates=df.duplicated()
sum(duplicates)
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   seqn               2401 non-null   int64
#  1   Age                2401 non-null   int64
#  2   Sex                2401 non-null   object
#  3   Marital            2193 non-null   object
#  4   Income             2284 non-null   float64
#  5   Race               2401 non-null   object
#  6   WaistCirc          2316 non-null   float64
#  7   BMI                2375 non-null   float64
#  8   Albuminuria        2401 non-null   int64
#  9   UrAlbCr            2401 non-null   float64
#  10  UricAcid           2401 non-null   float64
#  11  BloodGlucose       2401 non-null   int64
#  12  HDL                2401 non-null   int64
#  13  Triglycerides      2401 non-null   int64
#  14  MetabolicSyndrome  2401 non-null   int64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 281.5+ KB

# %%
# Convert 'Albuminuria' column to object type
df['Albuminuria'] =df['Albuminuria'].astype('object')

# Optional: Check the result
print(df.dtypes['Albuminuria'])

# Convert 'Albuminuria' column to object type
df['MetabolicSyndrome'] =df['MetabolicSyndrome'].astype('object')

# Optional: Check the result
print(df.dtypes['MetabolicSyndrome'])
# Out:
# object
# object

# %%
df.describe()
# Out:
#                seqn          Age       Income    WaistCirc          BMI  \
# count   2401.000000  2401.000000  2284.000000  2316.000000  2375.000000
# mean   67030.674302    48.691795  4005.253940    98.307254    28.702189
# std     2823.565114    17.632852  2954.032186    16.252634     6.662242
# min    62161.000000    20.000000   300.000000    56.200000    13.400000
# 25%    64591.000000    34.000000  1600.000000    86.675000    24.000000
# 50%    67059.000000    48.000000  2500.000000    97.000000    27.700000
# 75%    69495.000000    63.000000  6200.000000   107.625000    32.100000
# max    71915.000000    80.000000  9000.000000   176.000000    68.700000
#
#            UrAlbCr     UricAcid  BloodGlucose          HDL  Triglycerides
# count  2401.000000  2401.000000   2401.000000  2401.000000    2401.000000
# mean     43.626131     5.489046    108.247813    53.369429     128.125364
# std     258.272829     1.439358     34.820657    15.185537      95.322477
# min       1.400000     1.800000     39.000000    14.000000      26.000000
# 25%       4.450000     4.500000     92.000000    43.000000      75.000000
# 50%       7.070000     5.400000     99.000000    51.000000     103.000000
# 75%      13.690000     6.400000    110.000000    62.000000     150.000000
# max    5928.000000    11.300000    382.000000   156.000000    1562.000000

# %%
from sklearn.model_selection import train_test_split

# If you have a target variable, add it here:
# quantile_df['target'] = df['YourTargetColumn']

# Split into train and test (80% train, 20% test)
train_df, test_df = train_test_split(
    df, 
    test_size=0.2, 
    random_state=42
)

# Check shape for confirmation
print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (1920, 15)
# Test shape: (481, 15)

# %%
###### EDA ######

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import math

columns_to_look = ["Sex", "Marital", "Race", "Albuminuria", "MetabolicSyndrome"]

# Grid setup: 2 plots per row
n_cols = 2
n_rows = math.ceil(len(columns_to_look) / n_cols)

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(9, 4 * n_rows))
axes = axes.flatten()
pie_train_df = train_df
for i, col in enumerate(columns_to_look):
    non_null_values = pie_train_df[col].dropna()
    value_counts = non_null_values.value_counts()
    labels = value_counts.index.tolist()
    pie_colors = sns.color_palette('Set2', len(labels))

    axes[i].pie(
        value_counts,
        labels=labels,
        shadow=True,
        explode=[0.05] * len(labels),
        autopct='%1.1f%%',
        textprops={'size': 12},
        colors=pie_colors,
        startangle=90
    )
    axes[i].set_title(f'{col} Distribution', fontsize=14)

# Hide unused axes if the number of columns is odd
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
print(f"Dimensions: {pie_train_df.shape}") 
print(f"Dimensions: {train_df.shape}")
# Out:
# Dimensions: (1920, 15)
# Dimensions: (1920, 15)

# %%
import pandas as pd

# Select numerical columns
numerical_cols = ['Age', 'Income', 'WaistCirc', 'BMI', 'UrAlbCr', 'UricAcid', 'BloodGlucose', 'HDL', 'Triglycerides']

# Generate summary statistics
summary = train_df[numerical_cols].describe(percentiles=[.25, .5, .75])
print(summary.loc[['min', 'max']])  # Show only min/max
# Out:
#       Age  Income  WaistCirc   BMI  UrAlbCr  UricAcid  BloodGlucose    HDL  \
# min  20.0   300.0       63.1  13.6      1.4       1.8          39.0   21.0
# max  80.0  9000.0      176.0  68.7   5928.0      11.3         382.0  156.0
#
#      Triglycerides
# min           26.0
# max         1562.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def plot_numeric_kde_boxplot(train_df, numeric_cols):
    # Define a list of Seaborn color palettes
    palette_list = ['Set1', 'Set2', 'Set3', 'tab10', 'Paired', 'Dark2', 'pastel']

    for i, col in enumerate(numeric_cols):
        fig, axes = plt.subplots(1, 2, figsize=(16, 5))
        
        # Pick a palette based on index (cyclic)
        palette = sns.color_palette(palette_list[i % len(palette_list)])
        color_hist = palette[0]
        color_box = palette[1] if len(palette) > 1 else palette[0]

        # KDE + Histogram
        sns.histplot(train_df, x=col, kde=True, color=color_hist, ax=axes[0])
        axes[0].set_title(f'{col} - Histogram & KDE', fontsize=14)

        # Boxplot
        sns.boxplot(train_df, y=col, color=color_box, ax=axes[1])
        axes[1].set_title(f'{col} - Boxplot', fontsize=14)

        # Overall title
        fig.suptitle(f'Numeric Feature: {col}', fontsize=16, fontweight='bold')
        fig.subplots_adjust(wspace=0.3)
        plt.tight_layout()
        plt.show()


numeric_cols = train_df.drop(columns=["seqn", "Albuminuria","MetabolicSyndrome"]).select_dtypes(include="number").columns
plot_numeric_kde_boxplot(train_df, numeric_cols)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import QuantileTransformer
transform_train_df = train_df
transform_test_df = test_df
# Variables to transform
variables = ["WaistCirc", "BMI", "UrAlbCr", "UricAcid", "BloodGlucose", "HDL", "Triglycerides"]

# Initialize transformers (fit only on train_df later)
quantile_tf = QuantileTransformer(output_distribution='normal', random_state=42)

# Store transformed test data (optional)
test_transformed = pd.DataFrame()

for var in variables:
    # Create figure
    fig, axes = plt.subplots(1, 3, figsize=(18, 4))
    
    # --- Training Data ---
    train_data = transform_train_df[var].dropna()
    
    # Apply transformations to TRAIN data
    log_trans_train = np.log1p(train_data)
    sqrt_trans_train = np.sqrt(train_data)
    quantile_trans_train = pd.Series(
        quantile_tf.fit_transform(train_data.values.reshape(-1, 1)).flatten(),  # Fit here
        index=train_data.index
    )
    
    # --- Test Data (transformed using train-fit transformers) ---
    test_data = transform_test_df[var].dropna()
    quantile_trans_test = pd.Series(
        quantile_tf.transform(test_data.values.reshape(-1, 1)).flatten(),  # No fit!
        index=test_data.index
    )
    # Store test transforms if needed
    test_transformed[f'{var}_quantile'] = quantile_trans_test
    
    # --- Plot TRAIN distributions ---
    sns.histplot(log_trans_train, ax=axes[0], kde=True, color='darkorange')
    axes[0].set_title(f'Train: {var} (Log)')
    
    sns.histplot(sqrt_trans_train, ax=axes[1], kde=True, color='seagreen')
    axes[1].set_title(f'Train: {var} (Sqrt)')
    
    sns.histplot(quantile_trans_train, ax=axes[2], kde=True, color='slateblue')
    axes[2].set_title(f'Train: {var} (Quantile)')
    
    fig.suptitle(f'Training Set Transformations: {var}', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()

# Optional: Add transformed test data to test_df
for var in variables:
    transform_test_df[f'{var}_quantile'] = test_transformed[f'{var}_quantile']

# %%
train_df
# Out:
#        seqn  Age     Sex  Marital  Income         Race  WaistCirc   BMI  \
# 174   62861   80  Female  Married  2000.0        White       74.4  18.4
# 420   63806   70    Male  Married  1700.0        White      108.3  30.2
# 1980  70212   40  Female  Married  2000.0        White       94.3  27.8
# 120   62635   27  Female  Married  2000.0        Asian       90.1  26.1
# 283   63287   78  Female  Widowed     NaN        Black       97.0  25.9
# ...     ...  ...     ...      ...     ...          ...        ...   ...
# 1638  68847   21    Male   Single  5400.0  MexAmerican      116.7  35.0
# 1095  66585   40    Male  Married  9000.0        Asian       93.3  27.1
# 1130  66763   80  Female  Married  3500.0        White       90.0  26.2
# 1294  67438   61    Male  Married  2000.0        Black      110.8  30.5
# 860   65647   29  Female  Married  2000.0        White      106.4  33.3
#
#      Albuminuria  UrAlbCr  UricAcid  BloodGlucose  HDL  Triglycerides  \
# 174            1    33.47       4.5           157   76             61
# 420            0     9.12       6.2           129   36            158
# 1980           0     6.97       4.4            93   40             94
# 120            0     5.50       6.1           118   44            283
# 283            2   535.85       7.8           244   53            126
# ...          ...      ...       ...           ...  ...            ...
# 1638           0     2.76       7.4           100   37            173
# 1095           0     3.51       5.5            89   52             83
# 1130           0    13.67       4.1           202   56             69
# 1294           1   138.79       7.1           108   53            146
# 860            0    19.22       6.1           105   34            131
#
#      MetabolicSyndrome
# 174                  0
# 420                  1
# 1980                 0
# 120                  1
# 283                  1
# ...                ...
# 1638                 1
# 1095                 0
# 1130                 1
# 1294                 1
# 860                  1
#
# [1920 rows x 15 columns]

# %%
import pandas as pd
from sklearn.preprocessing import QuantileTransformer
transform_train_df = train_df 
# Variables to transform
variables = ["WaistCirc", "BMI", "UrAlbCr", "UricAcid", "BloodGlucose", "HDL", "Triglycerides"]

# Initialize transformer (fit only on train data)
quantile_tf = QuantileTransformer(output_distribution='normal', random_state=42)

# --- Transform TRAIN data ---
# Fit and transform training data
train_quantile = pd.DataFrame(
    quantile_tf.fit_transform(transform_train_df[variables]),
    columns=[f"{var}_quantile" for var in variables],
    index=transform_train_df.index
)

# --- Transform TEST data ---
# Use same transformer (no fitting)
transform_test_df = test_df
test_quantile = pd.DataFrame(
    quantile_tf.transform(transform_test_df[variables]),
    columns=[f"{var}_quantile" for var in variables],
    index=transform_test_df.index
)

# --- Update DataFrames ---
# 1. Drop original variables
transform_train_df = transform_train_df.drop(columns=variables)
transform_test_df = transform_test_df.drop(columns=variables)
train_df = train_df.drop(columns=variables)
test_df = test_df.drop(columns=variables)

# 2. Add transformed versions
transform_train_df = pd.concat([transform_train_df, train_quantile], axis=1)
transform_test_df = pd.concat([transform_test_df, test_quantile], axis=1)

# Verify
print("Train columns:", transform_train_df.columns.tolist())
print("Test columns:", transform_test_df.columns.tolist())
print("Train columns:", train_df.columns.tolist())
print("Test columns:", test_df.columns.tolist())
# Out:
# Train columns: ['seqn', 'Age', 'Sex', 'Marital', 'Income', 'Race', 'Albuminuria', 'MetabolicSyndrome', 'WaistCirc_quantile', 'BMI_quantile', 'UrAlbCr_quantile', 'UricAcid_quantile', 'BloodGlucose_quantile', 'HDL_quantile', 'Triglycerides_quantile']
# Test columns: ['seqn', 'Age', 'Sex', 'Marital', 'Income', 'Race', 'Albuminuria', 'MetabolicSyndrome', 'WaistCirc_quantile', 'BMI_quantile', 'UrAlbCr_quantile', 'UricAcid_quantile', 'BloodGlucose_quantile', 'HDL_quantile', 'Triglycerides_quantile', 'WaistCirc_quantile', 'BMI_quantile', 'UrAlbCr_quantile', 'UricAcid_quantile', 'BloodGlucose_quantile', 'HDL_quantile', 'Triglycerides_quantile']
# Train columns: ['seqn', 'Age', 'Sex', 'Marital', 'Income', 'Race', 'Albuminuria', 'MetabolicSyndrome']
# Test columns: ['seqn', 'Age', 'Sex', 'Marital', 'Income', 'Race', 'Albuminuria', 'MetabolicSyndrome', 'WaistCirc_quantile', 'BMI_quantile', 'UrAlbCr_quantile', 'UricAcid_quantile', 'BloodGlucose_quantile', 'HDL_quantile', 'Triglycerides_quantile']

# %%
# Total missing values per column
missing_counts = train_df.isnull().sum()
missing_percent = (missing_counts / len(train_df)) * 100

# Summary table
missing_summary = pd.DataFrame({
    'Missing Count': missing_counts,
    'Missing %': missing_percent
}).sort_values('Missing %', ascending=False)

print(missing_summary)
# Out:
#                    Missing Count  Missing %
# Marital                      159   8.281250
# Income                        93   4.843750
# WaistCirc                     65   3.385417
# BMI                           24   1.250000
# seqn                           0   0.000000
# Age                            0   0.000000
# Sex                            0   0.000000
# Race                           0   0.000000
# Albuminuria                    0   0.000000
# UrAlbCr                        0   0.000000
# UricAcid                       0   0.000000
# BloodGlucose                   0   0.000000
# HDL                            0   0.000000
# Triglycerides                  0   0.000000
# MetabolicSyndrome              0   0.000000

# %%
import missingno as msno
import matplotlib.pyplot as plt

# Matrix plot (shows gaps in data)
msno.matrix(train_df)
plt.title("Missing Data Patterns")
plt.show()

# Heatmap (correlation of missingness across columns)
msno.heatmap(train_df)
plt.title("Missing Data Correlation")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import missingno as msno
#       2 import matplotlib.pyplot as plt
#       4 # Matrix plot (shows gaps in data)
#
# ModuleNotFoundError: No module named 'missingno'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import math

columns_to_look = ["Sex", "Marital", "Race", "Albuminuria", "MetabolicSyndrome"]

# Grid setup: 2 plots per row
n_cols = 2
n_rows = math.ceil(len(columns_to_look) / n_cols)

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(9, 4 * n_rows))
axes = axes.flatten()

for i, col in enumerate(columns_to_look):
    non_null_values = df[col].dropna()
    value_counts = non_null_values.value_counts()
    labels = value_counts.index.tolist()
    pie_colors = sns.color_palette('Set2', len(labels))

    axes[i].pie(
        value_counts,
        labels=labels,
        shadow=True,
        explode=[0.05] * len(labels),
        autopct='%1.1f%%',
        textprops={'size': 12},
        colors=pie_colors,
        startangle=90
    )
    axes[i].set_title(f'{col} Distribution', fontsize=14)

# Hide unused axes if the number of columns is odd
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
